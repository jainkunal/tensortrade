# %%
import sys
sys.path.insert(0, '/code')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import tensortrade.env.default as default

from tensortrade.oms.exchanges import Exchange
from tensortrade.feed.core import Stream, DataFeed
from tensortrade.oms.instruments import USD, EUR
from tensortrade.oms.wallets import Wallet, Portfolio
from tensortrade.oms.services.execution.simulated import execute_order
from tensortrade.agents import DQNAgent
from ray import tune
from ray.tune.registry import register_env

# %% [markdown]
# ## Load Data
# EURUSD data is being loaded from local directory

# %%
data = pd.read_csv('data/EURUSD_Candlestick_1_M_BID_01.12.2017-30.11.2020.csv')
data = data.rename(columns={"Local time": "Date"})

# %%
data.head()
# Out:
#                                Date     Open     High      Low    Close  \
# 0  01.12.2017 00:00:00.000 GMT-0500  1.19109  1.19113  1.19106  1.19111
# 1  01.12.2017 00:01:00.000 GMT-0500  1.19110  1.19110  1.19108  1.19108
# 2  01.12.2017 00:02:00.000 GMT-0500  1.19107  1.19107  1.19099  1.19100
# 3  01.12.2017 00:03:00.000 GMT-0500  1.19099  1.19104  1.19099  1.19104
# 4  01.12.2017 00:04:00.000 GMT-0500  1.19104  1.19105  1.19101  1.19104
#
#    Volume
# 0  105.63
# 1   43.82
# 2  163.81
# 3  144.37
# 4   68.71

# %% [markdown]
# ## Features

# %%
def rsi(price: Stream[float], period: float) -> Stream[float]:
    r = price.diff()
    upside = r.clamp_min(0).abs()
    downside = r.clamp_max(0).abs()
    rs = upside.ewm(alpha=1 / period).mean() / downside.ewm(alpha=1 / period).mean()
    return 100*(1 - (1 + rs) ** -1)


def macd(price: Stream[float], fast: float, slow: float, signal: float) -> Stream[float]:
    fm = price.ewm(span=fast, adjust=False).mean()
    sm = price.ewm(span=slow, adjust=False).mean()
    md = fm - sm
    signal = md - md.ewm(span=signal, adjust=False).mean()
    return signal


features = []
for c in data.columns[1:]:
    s = Stream.source(list(data[c]), dtype="float").rename(data[c].name)
    features += [s]

cp = Stream.select(features, lambda s: s.name == "Close")

features = features + [
    cp.log().diff().rename("lr"),
    rsi(cp, period=20).rename("rsi"),
    macd(cp, fast=10, slow=50, signal=5).rename("macd"),
]

feed = DataFeed(features)
feed.compile()

# %% [markdown]
# ## Setup Environment

# %%
forex = Exchange("forex", service=execute_order)(
    Stream.source(list(data["Close"]), dtype="float").rename("USD/EUR")  # works but understand
)

portfolio = Portfolio(USD, [
    Wallet(forex, 10000 * USD),
    Wallet(forex, 10 * EUR)
])

renderer_feed = DataFeed([
    Stream.source(list(data["Date"])).rename("date"),
    Stream.source(list(data["Open"]), dtype="float").rename("open"),
    Stream.source(list(data["High"]), dtype="float").rename("high"),
    Stream.source(list(data["Low"]), dtype="float").rename("low"),
    Stream.source(list(data["Close"]), dtype="float").rename("close"), 
    Stream.source(list(data["Volume"]), dtype="float").rename("volume") 
])

env = default.create(
    portfolio=portfolio,
    action_scheme=default.actions.SimpleOrders(trade_sizes=1),
    reward_scheme="simple",
    feed=feed,
    renderer_feed=renderer_feed,
#     renderer=default.renderers.PlotlyTradingChart(display=False),
    window_size=10,
    warmup_random_periods=True
)

# %%
register_env("TradingEnv", lambda config: env)

# %%
analysis = tune.run(
    "PPO",
    stop={
      "timesteps_total": 8
    },
    config={
        "env": "TradingEnv",
        "env_config": {
            "window_size": 10
        },
        "log_level": "WARN",
        "framework": "tfe",
        "ignore_worker_failures": True,
        "num_workers": 1,
        "num_gpus": 0,
        "clip_rewards": True,
        "lr": 8e-6,
        "lr_schedule": [
            [0, 1e-1],
            [int(1e2), 1e-2],
            [int(1e3), 1e-3],
            [int(1e4), 1e-4],
            [int(1e5), 1e-5],
            [int(1e6), 1e-6],
            [int(1e7), 1e-7]
        ],
        "gamma": 0,
        "observation_filter": "MeanStdFilter",
        "lambda": 0.72,
        "vf_loss_coeff": 0.5,
        "entropy_coeff": 0.01
    },
    checkpoint_at_end=True
)

# %%
agent = DQNAgent(env)

agent.train(n_steps=2000, n_episodes=1, save_path="agents/", update_target_every=100)
# Out:
# ====      AGENT ID: 6b54167d-b5ba-4572-9fab-d0299ff6d2cc      ====
# -6674108.036772495
# 0

# %%
portfolio.performance
# Out:
# OrderedDict([(0,
#               {'forex:/USD/EUR': 1.1916200000000001,
#                'forex:/USD:/free': 10000.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 10000.0,
#                'forex:/EUR:/free': 10.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 10.0,
#                'forex:/EUR:/worth': 11.916200000000002,
#                'net_worth': 10011.9162,
#                'base_symbol': 'USD'}),
#              (1,
#               {'forex:/USD/EUR': 1.19154,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9994.816251,
#                'net_worth': 9994.816251,
#                'base_symbol': 'USD'}),
#              (2,
#               {'forex:/USD/EUR': 1.19161,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9995.4034215,
#                'net_worth': 9995.4034215,
#                'base_symbol': 'USD'}),
#              (3,
#               {'forex:/USD/EUR': 1.19161,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9995.4034215,
#                'net_worth': 9995.4034215,
#                'base_symbol': 'USD'}),
#              (4,
#               {'forex:/USD/EUR': 1.1914200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9993.809673000002,
#                'net_worth': 9993.809673000002,
#                'base_symbol': 'USD'}),
#              (5,
#               {'forex:/USD/EUR': 1.19134,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9993.138621,
#                'net_worth': 9993.138621,
#                'base_symbol': 'USD'}),
#              (6,
#               {'forex:/USD/EUR': 1.19146,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9994.145198999999,
#                'net_worth': 9994.145198999999,
#                'base_symbol': 'USD'}),
#              (7,
#               {'forex:/USD/EUR': 1.19131,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9992.8869765,
#                'net_worth': 9992.8869765,
#                'base_symbol': 'USD'}),
#              (8,
#               {'forex:/USD/EUR': 1.19131,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9992.8869765,
#                'net_worth': 9992.8869765,
#                'base_symbol': 'USD'}),
#              (9,
#               {'forex:/USD/EUR': 1.1912399999999999,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8388.15,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8388.15,
#                'forex:/EUR:/worth': 9992.299805999999,
#                'net_worth': 9992.299805999999,
#                'base_symbol': 'USD'}),
#              (10,
#               {'forex:/USD/EUR': 1.19119,
#                'forex:/USD:/free': 9951.96,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9951.96,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9951.96,
#                'base_symbol': 'USD'}),
#              (11,
#               {'forex:/USD/EUR': 1.19108,
#                'forex:/USD:/free': 9951.96,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9951.96,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9951.96,
#                'base_symbol': 'USD'}),
#              (12,
#               {'forex:/USD/EUR': 1.19095,
#                'forex:/USD:/free': 9951.96,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9951.96,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9951.96,
#                'base_symbol': 'USD'}),
#              (13,
#               {'forex:/USD/EUR': 1.19084,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9929.104835999999,
#                'net_worth': 9929.104835999999,
#                'base_symbol': 'USD'}),
#              (14,
#               {'forex:/USD/EUR': 1.19072,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9928.104288,
#                'net_worth': 9928.104288,
#                'base_symbol': 'USD'}),
#              (15,
#               {'forex:/USD/EUR': 1.19099,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9930.355521,
#                'net_worth': 9930.355521,
#                'base_symbol': 'USD'}),
#              (16,
#               {'forex:/USD/EUR': 1.1911200000000002,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9931.439448000001,
#                'net_worth': 9931.439448000001,
#                'base_symbol': 'USD'}),
#              (17,
#               {'forex:/USD/EUR': 1.191,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9930.4389,
#                'net_worth': 9930.4389,
#                'base_symbol': 'USD'}),
#              (18,
#               {'forex:/USD/EUR': 1.1908100000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9928.854699000001,
#                'net_worth': 9928.854699000001,
#                'base_symbol': 'USD'}),
#              (19,
#               {'forex:/USD/EUR': 1.1914,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9933.77406,
#                'net_worth': 9933.77406,
#                'base_symbol': 'USD'}),
#              (20,
#               {'forex:/USD/EUR': 1.19156,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9935.108123999998,
#                'net_worth': 9935.108123999998,
#                'base_symbol': 'USD'}),
#              (21,
#               {'forex:/USD/EUR': 1.1915200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9934.774608000002,
#                'net_worth': 9934.774608000002,
#                'base_symbol': 'USD'}),
#              (22,
#               {'forex:/USD/EUR': 1.1914799999999999,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8337.9,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8337.9,
#                'forex:/EUR:/worth': 9934.441092,
#                'net_worth': 9934.441092,
#                'base_symbol': 'USD'}),
#              (23,
#               {'forex:/USD/EUR': 1.19224,
#                'forex:/USD:/free': 9892.34,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9892.34,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9892.34,
#                'base_symbol': 'USD'}),
#              (24,
#               {'forex:/USD/EUR': 1.19231,
#                'forex:/USD:/free': 9892.34,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9892.34,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9892.34,
#                'base_symbol': 'USD'}),
#              (25,
#               {'forex:/USD/EUR': 1.19248,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8287.95,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8287.95,
#                'forex:/EUR:/worth': 9883.214616000001,
#                'net_worth': 9883.214616000001,
#                'base_symbol': 'USD'}),
#              (26,
#               {'forex:/USD/EUR': 1.1929299999999998,
#                'forex:/USD:/free': 9833.08,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9833.08,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9833.08,
#                'base_symbol': 'USD'}),
#              (27,
#               {'forex:/USD/EUR': 1.1925299999999999,
#                'forex:/USD:/free': 9833.08,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9833.08,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9833.08,
#                'base_symbol': 'USD'}),
#              (28,
#               {'forex:/USD/EUR': 1.19231,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8238.3,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8238.3,
#                'forex:/EUR:/worth': 9822.607472999998,
#                'net_worth': 9822.607472999998,
#                'base_symbol': 'USD'}),
#              (29,
#               {'forex:/USD/EUR': 1.19201,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8238.3,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8238.3,
#                'forex:/EUR:/worth': 9820.135983,
#                'net_worth': 9820.135983,
#                'base_symbol': 'USD'}),
#              (30,
#               {'forex:/USD/EUR': 1.19211,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8238.3,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8238.3,
#                'forex:/EUR:/worth': 9820.959813,
#                'net_worth': 9820.959813,
#                'base_symbol': 'USD'}),
#              (31,
#               {'forex:/USD/EUR': 1.1923,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (32,
#               {'forex:/USD/EUR': 1.19195,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (33,
#               {'forex:/USD/EUR': 1.1917200000000001,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (34,
#               {'forex:/USD/EUR': 1.19256,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (35,
#               {'forex:/USD/EUR': 1.19275,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (36,
#               {'forex:/USD/EUR': 1.19282,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (37,
#               {'forex:/USD/EUR': 1.19256,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (38,
#               {'forex:/USD/EUR': 1.1925700000000001,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (39,
#               {'forex:/USD/EUR': 1.19265,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (40,
#               {'forex:/USD/EUR': 1.1929100000000001,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (41,
#               {'forex:/USD/EUR': 1.19288,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (42,
#               {'forex:/USD/EUR': 1.19286,
#                'forex:/USD:/free': 9774.17,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9774.17,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9774.17,
#                'base_symbol': 'USD'}),
#              (43,
#               {'forex:/USD/EUR': 1.19289,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8188.95,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8188.95,
#                'forex:/EUR:/worth': 9768.5165655,
#                'net_worth': 9768.5165655,
#                'base_symbol': 'USD'}),
#              (44,
#               {'forex:/USD/EUR': 1.19294,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8188.95,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8188.95,
#                'forex:/EUR:/worth': 9768.926012999998,
#                'net_worth': 9768.926012999998,
#                'base_symbol': 'USD'}),
#              (45,
#               {'forex:/USD/EUR': 1.19306,
#                'forex:/USD:/free': 9715.61,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9715.61,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9715.61,
#                'base_symbol': 'USD'}),
#              (46,
#               {'forex:/USD/EUR': 1.19339,
#                'forex:/USD:/free': 9715.61,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9715.61,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9715.61,
#                'base_symbol': 'USD'}),
#              (47,
#               {'forex:/USD/EUR': 1.19357,
#                'forex:/USD:/free': 9715.61,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9715.61,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9715.61,
#                'base_symbol': 'USD'}),
#              (48,
#               {'forex:/USD/EUR': 1.1933,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8139.88,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8139.88,
#                'forex:/EUR:/worth': 9713.318804,
#                'net_worth': 9713.318804,
#                'base_symbol': 'USD'}),
#              (49,
#               {'forex:/USD/EUR': 1.19327,
#                'forex:/USD:/free': 9657.4,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9657.4,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9657.4,
#                'base_symbol': 'USD'}),
#              (50,
#               {'forex:/USD/EUR': 1.1932,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9654.324384,
#                'net_worth': 9654.324384,
#                'base_symbol': 'USD'}),
#              (51,
#               {'forex:/USD/EUR': 1.19326,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9654.8098512,
#                'net_worth': 9654.8098512,
#                'base_symbol': 'USD'}),
#              (52,
#               {'forex:/USD/EUR': 1.19357,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9657.3180984,
#                'net_worth': 9657.3180984,
#                'base_symbol': 'USD'}),
#              (53,
#               {'forex:/USD/EUR': 1.19296,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9652.3825152,
#                'net_worth': 9652.3825152,
#                'base_symbol': 'USD'}),
#              (54,
#               {'forex:/USD/EUR': 1.19347,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9656.5089864,
#                'net_worth': 9656.5089864,
#                'base_symbol': 'USD'}),
#              (55,
#               {'forex:/USD/EUR': 1.19392,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9660.149990400001,
#                'net_worth': 9660.149990400001,
#                'base_symbol': 'USD'}),
#              (56,
#               {'forex:/USD/EUR': 1.19361,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9657.6417432,
#                'net_worth': 9657.6417432,
#                'base_symbol': 'USD'}),
#              (57,
#               {'forex:/USD/EUR': 1.19344,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9656.2662528,
#                'net_worth': 9656.2662528,
#                'base_symbol': 'USD'}),
#              (58,
#               {'forex:/USD/EUR': 1.19385,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8091.12,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8091.12,
#                'forex:/EUR:/worth': 9659.583612,
#                'net_worth': 9659.583612,
#                'base_symbol': 'USD'}),
#              (59,
#               {'forex:/USD/EUR': 1.19364,
#                'forex:/USD:/free': 9599.55,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9599.55,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9599.55,
#                'base_symbol': 'USD'}),
#              (60,
#               {'forex:/USD/EUR': 1.19366,
#                'forex:/USD:/free': 9599.55,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9599.55,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9599.55,
#                'base_symbol': 'USD'}),
#              (61,
#               {'forex:/USD/EUR': 1.19351,
#                'forex:/USD:/free': 9599.55,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9599.55,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9599.55,
#                'base_symbol': 'USD'}),
#              (62,
#               {'forex:/USD/EUR': 1.19344,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8042.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8042.65,
#                'forex:/EUR:/worth': 9598.420216,
#                'net_worth': 9598.420216,
#                'base_symbol': 'USD'}),
#              (63,
#               {'forex:/USD/EUR': 1.193,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8042.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8042.65,
#                'forex:/EUR:/worth': 9594.88145,
#                'net_worth': 9594.88145,
#                'base_symbol': 'USD'}),
#              (64,
#               {'forex:/USD/EUR': 1.19356,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8042.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8042.65,
#                'forex:/EUR:/worth': 9599.385333999999,
#                'net_worth': 9599.385333999999,
#                'base_symbol': 'USD'}),
#              (65,
#               {'forex:/USD/EUR': 1.19326,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8042.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8042.65,
#                'forex:/EUR:/worth': 9596.972539,
#                'net_worth': 9596.972539,
#                'base_symbol': 'USD'}),
#              (66,
#               {'forex:/USD/EUR': 1.19345,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 8042.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 8042.65,
#                'forex:/EUR:/worth': 9598.5006425,
#                'net_worth': 9598.5006425,
#                'base_symbol': 'USD'}),
#              (67,
#               {'forex:/USD/EUR': 1.1934,
#                'forex:/USD:/free': 9542.04,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9542.04,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9542.04,
#                'base_symbol': 'USD'}),
#              (68,
#               {'forex:/USD/EUR': 1.19329,
#                'forex:/USD:/free': 9542.04,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9542.04,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9542.04,
#                'base_symbol': 'USD'}),
#              (69,
#               {'forex:/USD/EUR': 1.19305,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7994.46,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7994.46,
#                'forex:/EUR:/worth': 9537.790503,
#                'net_worth': 9537.790503,
#                'base_symbol': 'USD'}),
#              (70,
#               {'forex:/USD/EUR': 1.19292,
#                'forex:/USD:/free': 9484.87,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9484.87,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9484.87,
#                'base_symbol': 'USD'}),
#              (71,
#               {'forex:/USD/EUR': 1.19327,
#                'forex:/USD:/free': 9484.87,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9484.87,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9484.87,
#                'base_symbol': 'USD'}),
#              (72,
#               {'forex:/USD/EUR': 1.19331,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9482.721446700001,
#                'net_worth': 9482.721446700001,
#                'base_symbol': 'USD'}),
#              (73,
#               {'forex:/USD/EUR': 1.19316,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9481.5294612,
#                'net_worth': 9481.5294612,
#                'base_symbol': 'USD'}),
#              (74,
#               {'forex:/USD/EUR': 1.1932,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9481.847324,
#                'net_worth': 9481.847324,
#                'base_symbol': 'USD'}),
#              (75,
#               {'forex:/USD/EUR': 1.1932399999999999,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9482.165186799999,
#                'net_worth': 9482.165186799999,
#                'base_symbol': 'USD'}),
#              (76,
#               {'forex:/USD/EUR': 1.1929100000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9479.542818700002,
#                'net_worth': 9479.542818700002,
#                'base_symbol': 'USD'}),
#              (77,
#               {'forex:/USD/EUR': 1.19295,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9479.860681499998,
#                'net_worth': 9479.860681499998,
#                'base_symbol': 'USD'}),
#              (78,
#               {'forex:/USD/EUR': 1.19302,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9480.416941399999,
#                'net_worth': 9480.416941399999,
#                'base_symbol': 'USD'}),
#              (79,
#               {'forex:/USD/EUR': 1.19297,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9480.0196129,
#                'net_worth': 9480.0196129,
#                'base_symbol': 'USD'}),
#              (80,
#               {'forex:/USD/EUR': 1.1929,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7946.57,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7946.57,
#                'forex:/EUR:/worth': 9479.463353000001,
#                'net_worth': 9479.463353000001,
#                'base_symbol': 'USD'}),
#              (81,
#               {'forex:/USD/EUR': 1.19274,
#                'forex:/USD:/free': 9428.05,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9428.05,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9428.05,
#                'base_symbol': 'USD'}),
#              (82,
#               {'forex:/USD/EUR': 1.19269,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7898.97,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7898.97,
#                'forex:/EUR:/worth': 9421.0225293,
#                'net_worth': 9421.0225293,
#                'base_symbol': 'USD'}),
#              (83,
#               {'forex:/USD/EUR': 1.1927,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7898.97,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7898.97,
#                'forex:/EUR:/worth': 9421.101519000002,
#                'net_worth': 9421.101519000002,
#                'base_symbol': 'USD'}),
#              (84,
#               {'forex:/USD/EUR': 1.19255,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7898.97,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7898.97,
#                'forex:/EUR:/worth': 9419.9166735,
#                'net_worth': 9419.9166735,
#                'base_symbol': 'USD'}),
#              (85,
#               {'forex:/USD/EUR': 1.19259,
#                'forex:/USD:/free': 9371.57,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9371.57,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9371.57,
#                'base_symbol': 'USD'}),
#              (86,
#               {'forex:/USD/EUR': 1.19225,
#                'forex:/USD:/free': 9371.57,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9371.57,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9371.57,
#                'base_symbol': 'USD'}),
#              (87,
#               {'forex:/USD/EUR': 1.19232,
#                'forex:/USD:/free': 9371.57,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9371.57,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9371.57,
#                'base_symbol': 'USD'}),
#              (88,
#               {'forex:/USD/EUR': 1.19231,
#                'forex:/USD:/free': 9371.57,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9371.57,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9371.57,
#                'base_symbol': 'USD'}),
#              (89,
#               {'forex:/USD/EUR': 1.19251,
#                'forex:/USD:/free': 9371.57,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9371.57,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9371.57,
#                'base_symbol': 'USD'}),
#              (90,
#               {'forex:/USD/EUR': 1.1922,
#                'forex:/USD:/free': 9371.57,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9371.57,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9371.57,
#                'base_symbol': 'USD'}),
#              (91,
#               {'forex:/USD/EUR': 1.1920600000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7851.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7851.65,
#                'forex:/EUR:/worth': 9359.637899000001,
#                'net_worth': 9359.637899000001,
#                'base_symbol': 'USD'}),
#              (92,
#               {'forex:/USD/EUR': 1.1921700000000002,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7851.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7851.65,
#                'forex:/EUR:/worth': 9360.5015805,
#                'net_worth': 9360.5015805,
#                'base_symbol': 'USD'}),
#              (93,
#               {'forex:/USD/EUR': 1.1924299999999999,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7851.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7851.65,
#                'forex:/EUR:/worth': 9362.5430095,
#                'net_worth': 9362.5430095,
#                'base_symbol': 'USD'}),
#              (94,
#               {'forex:/USD/EUR': 1.19238,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7851.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7851.65,
#                'forex:/EUR:/worth': 9362.150426999999,
#                'net_worth': 9362.150426999999,
#                'base_symbol': 'USD'}),
#              (95,
#               {'forex:/USD/EUR': 1.1923700000000002,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7851.65,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7851.65,
#                'forex:/EUR:/worth': 9362.0719105,
#                'net_worth': 9362.0719105,
#                'base_symbol': 'USD'}),
#              (96,
#               {'forex:/USD/EUR': 1.19223,
#                'forex:/USD:/free': 9315.44,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9315.44,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9315.44,
#                'base_symbol': 'USD'}),
#              (97,
#               {'forex:/USD/EUR': 1.19208,
#                'forex:/USD:/free': 9315.44,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9315.44,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9315.44,
#                'base_symbol': 'USD'}),
#              (98,
#               {'forex:/USD/EUR': 1.19202,
#                'forex:/USD:/free': 9315.44,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9315.44,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9315.44,
#                'base_symbol': 'USD'}),
#              (99,
#               {'forex:/USD/EUR': 1.19195,
#                'forex:/USD:/free': 9315.44,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9315.44,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9315.44,
#                'base_symbol': 'USD'}),
#              (100,
#               {'forex:/USD/EUR': 1.1921700000000002,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7804.61,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7804.61,
#                'forex:/EUR:/worth': 9304.4219037,
#                'net_worth': 9304.4219037,
#                'base_symbol': 'USD'}),
#              (101,
#               {'forex:/USD/EUR': 1.19213,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7804.61,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7804.61,
#                'forex:/EUR:/worth': 9304.109719299999,
#                'net_worth': 9304.109719299999,
#                'base_symbol': 'USD'}),
#              (102,
#               {'forex:/USD/EUR': 1.19181,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7804.61,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7804.61,
#                'forex:/EUR:/worth': 9301.6122441,
#                'net_worth': 9301.6122441,
#                'base_symbol': 'USD'}),
#              (103,
#               {'forex:/USD/EUR': 1.19177,
#                'forex:/USD:/free': 9259.63,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9259.63,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9259.63,
#                'base_symbol': 'USD'}),
#              (104,
#               {'forex:/USD/EUR': 1.19161,
#                'forex:/USD:/free': 9259.63,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 9259.63,
#                'forex:/EUR:/free': 0.0,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 0.0,
#                'forex:/EUR:/worth': 0.0,
#                'net_worth': 9259.63,
#                'base_symbol': 'USD'}),
#              (105,
#               {'forex:/USD/EUR': 1.19191,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7757.86,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7757.86,
#                'forex:/EUR:/worth': 9246.6709126,
#                'net_worth': 9246.6709126,
#                'base_symbol': 'USD'}),
#              (106,
#               {'forex:/USD/EUR': 1.19201,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7757.86,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7757.86,
#                'forex:/EUR:/worth': 9247.446698599999,
#                'net_worth': 9247.446698599999,
#                'base_symbol': 'USD'}),
#              (107,
#               {'forex:/USD/EUR': 1.19205,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 7757.86,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 7757.86,
#                'forex:/EUR:/worth': 9247.757013,
#                'net_worth': 9247.757013,
#                'base_symbol': 'USD'}),
#              (108,
#               {'forex:/USD/EUR': 1.1918,
#                'forex:/USD:/free': 9204.16,
#                'forex:/USD:/locked': 0.0,
# ...
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (966,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (967,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (968,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (969,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (970,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (971,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (972,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (973,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (974,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (975,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (976,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (977,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (978,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (979,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (980,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (981,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (982,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (983,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (984,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (985,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (986,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (987,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (988,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (989,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (990,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (991,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (992,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (993,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (994,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (995,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (996,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (997,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (998,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              (999,
#               {'forex:/USD/EUR': 1.1894200000000001,
#                'forex:/USD:/free': 0.0,
#                'forex:/USD:/locked': 0.0,
#                'forex:/USD:/total': 0.0,
#                'forex:/EUR:/free': 5574.58,
#                'forex:/EUR:/locked': 0.0,
#                'forex:/EUR:/total': 5574.58,
#                'forex:/EUR:/worth': 6630.516943600001,
#                'net_worth': 6630.516943600001,
#                'base_symbol': 'USD'}),
#              ...])

# %%
import numpy as np
net_worths = [nw['net_worth'] for nw in portfolio.performance.values()]
returns = [(b - a) / a for a, b in zip(net_worths[::1], net_worths[1::1])]
returns = np.array([x + 1 for x in returns[:10]])
returns
# Out:
# array([0.99758931, 0.99992441, 1.00010919, 0.99973966, 0.9999244 ,
#        1.00008401, 1.000084  , 0.9999916 , 1.00015119, 0.99986563])

# %%
np.array([x+1 for x in returns[:10]]).cumprod() - 1
# Out:
# array([-0.00241069, -0.00248609, -0.00237718, -0.0026369 , -0.0027123 ,
#        -0.00262852, -0.00254474, -0.00255312, -0.00240231, -0.00253636])

# %%
zip(net_worths[::1], net_worths[1::1])

# %%
agent.save("agents/")

# %%
agent.id
# Out:
# '231b8001-7556-4821-8b04-148cfb8b94d9'

# %%
env.reset()
# Out:
# array([[ 1.18575001e+00,  1.18587005e+00,  1.18561006e+00,
#          1.18587005e+00,  3.09899994e+02,  1.01196652e-04,
#          4.37400017e+01,  2.68785334e-05],
#        [ 1.18587995e+00,  1.18587995e+00,  1.18568003e+00,
#          1.18572998e+00,  2.23570007e+02, -1.18063756e-04,
#          4.16770935e+01,  3.33465941e-05],
#        [ 1.18575001e+00,  1.18576002e+00,  1.18529999e+00,
#          1.18553996e+00,  3.54910004e+02, -1.60251686e-04,
#          3.90463181e+01,  1.90899991e-05],
#        [ 1.18554997e+00,  1.18562996e+00,  1.18527997e+00,
#          1.18559003e+00,  3.07459991e+02,  4.21739860e-05,
#          4.00938110e+01,  1.78276623e-05],
#        [ 1.18560004e+00,  1.18572998e+00,  1.18536997e+00,
#          1.18552995e+00,  3.29579987e+02, -5.06089964e-05,
#          3.92419701e+01,  1.29712698e-05],
#        [ 1.18552995e+00,  1.18578005e+00,  1.18552005e+00,
#          1.18573999e+00,  3.08989990e+02,  1.77120281e-04,
#          4.36525917e+01,  3.22383312e-05],
#        [ 1.18571997e+00,  1.18592000e+00,  1.18571997e+00,
#          1.18580997e+00,  3.07029999e+02,  5.90331219e-05,
#          4.50521851e+01,  4.92960971e-05],
#        [ 1.18579996e+00,  1.18604004e+00,  1.18577003e+00,
#          1.18598998e+00,  2.37289993e+02,  1.51783461e-04,
#          4.85137291e+01,  7.42390766e-05],
#        [ 1.18599999e+00,  1.18618000e+00,  1.18585002e+00,
#          1.18611002e+00,  2.74420013e+02,  1.01176171e-04,
#          5.06934929e+01,  9.55368450e-05],
#        [ 1.18608999e+00,  1.18612003e+00,  1.18597996e+00,
#          1.18603003e+00,  3.39750000e+02, -6.74496478e-05,
#          4.92308426e+01,  9.40637619e-05]], dtype=float32)

# %%
steps = 0
env.reset()
import numpy as np
while True:
    action = np.random.randint(0, 3)
    obs, rew, done, info = env.step(action)
    print(action)
#     print(obs)
    print(rew)
    steps += 1
    if steps == 10:
        break
# Out:
# [10011.9266, 10011.9317]
# 2
# 11.931699999999182
# [10011.9266, 10011.9317, 10010.3343285]
# 1
# 10.334328499999174
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999]
# 1
# 3.204400999999052
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96]
# 2
# -48.04000000000087
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96, 9951.96]
# 2
# -48.04000000000087
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96, 9951.96, 9951.96]
# 0
# -48.04000000000087
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96, 9951.96, 9951.96, 9951.96]
# 2
# -48.04000000000087
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96, 9951.96, 9951.96, 9951.96, 9951.96]
# 0
# -48.04000000000087
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96, 9951.96, 9951.96, 9951.96, 9951.96, 9951.96]
# 2
# -48.04000000000087
# [10011.9266, 10011.9317, 10010.3343285, 10003.204400999999, 9951.96, 9951.96, 9951.96, 9951.96, 9951.96, 9951.96, 9944.61333]
# 1
# -55.38666999999987

# %%
env.observer.feed.next()
# Out:
# {'internal': {'forex:/USD/EUR': 1.19129,
#   'forex:/USD:/free': 9951.96,
#   'forex:/USD:/locked': 0.0,
#   'forex:/USD:/total': 9951.96,
#   'forex:/EUR:/free': 0.0,
#   'forex:/EUR:/locked': 0.0,
#   'forex:/EUR:/total': 0.0,
#   'forex:/EUR:/worth': 0.0,
#   'net_worth': 9951.96},
#  'external': {'Open': 1.19127,
#   'High': 1.1913,
#   'Low': 1.19126,
#   'Close': 1.19129,
#   'Volume': 67.95,
#   'lr': 1.678866429419279e-05,
#   'rsi': 54.58181000433198,
#   'macd': -2.1827504042260573e-05},
#  'renderer': {'date': '01.12.2017 00:23:00.000 GMT-0500',
#   'open': 1.19127,
#   'high': 1.1913,
#   'low': 1.19126,
#   'close': 1.19129,
#   'volume': 67.95}}
